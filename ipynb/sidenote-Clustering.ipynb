# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
import warnings; warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
# %store -r train_df

# %%
is_dtype_num = train_df.dtypes.isin([np.dtype('float64'), np.dtype('int64')])
num_feats = train_df.dtypes.index[is_dtype_num]
num_df = train_df[num_feats]

# %%
# %store -r X_scaled
z_num_df = X_scaled[['LotFrontage', 'MasVnrArea']]
kmeans = KMeans(n_clusters=2, random_state=0).fit(z_num_df)

ctrs_x = []; ctrs_y = []
for i in range(2):
    x = kmeans.cluster_centers_[i][0]
    ctrs_x.append(x)
    y = kmeans.cluster_centers_[i][1]
    ctrs_y.append(y)

plt.scatter(z_num_df.LotFrontage, z_num_df.MasVnrArea,
            c = kmeans.labels_)

plt.scatter(ctrs_y, ctrs_x)
