# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn import neighbors
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn import svm
import warnings; warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV, ShuffleSplit, StratifiedShuffleSplit, train_test_split
import sklearn.preprocessing as preprocessing
import matplotlib.pyplot as plt

# %%
# %store -r

# %%
# %store
# Out:
# Stored variables and their in-db values:
# X                    ->       LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFin
# X_scaled             ->       LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFin
# train_df             ->      MSZoning  LotFrontage Street Alley LotShape L
# y                    -> Id
# 1       208500
# 2       181500
# 3       223500
# 4
# y_scaled             -> Id
# 1       0.349000
# 2       0.008854
# 3       0.537

# %% [markdown]
# ### Fitting Regression Models Using Default Settings

# %% [markdown]
# ### Linear Models: Ridge and Lasso
# Ridge and lasso is just ordinary least squares (OLS) linear regression subject to constraints to reduce the variance of the our coefficient estimators. Unlike OLS, it is not unbiased (according to Gauss-Markov Theorem) but when our features are highly correlated, our coefficient estimators have high variance.
#
# From the $R^{2}$, which is the proportion of the explained variance to the total variance, we see that our dataset is very linear and linear regression is appropriate. Because it is linear, using ANOVA for feature selection/elimination was appropriate.
#
# Lasso can be preferable to Ridge regression because Lasso usually helps with feature selection. Lasso regression subjects our linear model to the constraint that the L1-norm of our coefficent estimator vector be less than some constant, unlike Ridge regression which uses the L2-norm. The L1-norm is pointy and the optimized linear regression subject to the L1-penalty usually "hits" an edge where coefficient estimators are zero or very small.
# Lasso was not necessary for feature selection in this case as we can see the ridge regression model is nearly identical to the lasso regression model.
#
# We can see from our coefficent estimators which feature is most useful for predicting sale. price. The larger the coeffient, the larger the "effect" (remember that association does not imply causation).
#
# Note: informal derivation of Ridge and Lasso in doc directory

# %% [markdown]
# #### Ridge

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_scaled, y) 

ridge_r2 = ridge.score(X_scaled,y); print(ridge_r2)

ridge.coef_

X_scaled.columns

def plot_coef(model, top_n = 10):
    '''
    Plots the magnitude of coefficients
    '''
    cols = X_scaled.columns
    coef = model.coef_
    zipped = list(zip(cols, coef))
    zipped.sort(key=lambda x: x[1], reverse = True)
    top_10 = pd.DataFrame(zipped).head(top_n)
    bottom_10 = pd.DataFrame(zipped).tail(top_n)
    return pd.concat([top_10, bottom_10], axis=0).plot.barh(x = 0, y = 1)

plot_coef(ridge)
# Out:
# 0.9420074505900202

# %% [markdown]
# #### Lasso

# %%
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(X_scaled, y)
print(lasso.score(X_scaled,y))
plot_coef(ridge)
# Out:
# 0.9420330146841008

# %% [markdown]
# #### K-Nearest-Neighbors
# KNN groups the data into some number of clusters that we pick. Imagine a two-dimensional dataset plotted. KNN would group them into some number of groups you specify based on their proximity to eachother. The distance can be determined using the Euclidean distance (recall Pythagorean Theorem). That distance formula generalizes to multiple dimensions so we can cluster in an infinite number of dimensions. Note that the distance formula used may be different.
#
# Using `GridSearchCV`, we see that the most optimal number of clusters is 9. The score for our knn using default settings, n_neighbors = 5, is higher than the score for the best paramater, n=9, because the first score gives us the $R^{2}$ of the training set rather than the validation set. Almost always the score for the training set is higher than the score for the validation set, but the score for the validation set is what's important.

# %%
knn = neighbors.KNeighborsRegressor(n_neighbors = 5)

# %%
knn.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
knn.score(X, y)
# Out:
# 0.8158678396654556

# %% [markdown]
# #### Decision Tree
# A decision tree regressor is like the usual decision tree classifier, except in the last node, the regressor predicts the sales price is the average of the subset an observation belongs to.

# %%
# think of random_state like random seed
dtree_regressor = DecisionTreeRegressor(random_state=0)
print(cross_val_score(dtree_regressor, X, y, cv=10))
# Out:
# [0.66464557 0.72397821 0.74206494 0.48614748 0.76144766 0.80121063
#  0.77397325 0.66254148 0.79044801 0.74609318]

# %% [markdown]
# #### Support Vector Machines
# Support vector machines work by splitting the data with a hyperplane. A hyperplane is a matrix with one-less dimension. For example, a line is a plane's  hyperplane. It's easier to think of it in two-dimensions and then generalize to n-dimensions. Support vector machines divide the dataset with a line.
#
# note: there's good youtube video on SVM classifiers @ https://youtu.be/N1vOgolbjSc

# %%
svRegression = svm.SVR()
svRegression.fit(X, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svRegression.score(X, y)
# Out:
# -0.050534340334851935

# %% [markdown]
# Let's try neighbors from 5 to 50 with intervals of 5. Ex: [5,10,15,...,45,50]

# %%
knn_params = {'n_neighbors': range(1,11,1)}

knn_gs = GridSearchCV(knn,
                     param_grid= knn_params,
                     cv = 10,
                     return_train_score = True)

knn_gs.fit(X, y)

#df.T = transpose of df
pd.DataFrame(knn_gs.cv_results_).T
# Out:
#                                      0                   1  \
# mean_fit_time                0.0336706            0.029345
# mean_score_time              0.0609085           0.0753832
# mean_test_score               0.582048            0.649678
# mean_train_score                     1            0.896565
# param_n_neighbors                    1                   2
# params              {'n_neighbors': 1}  {'n_neighbors': 2}
# rank_test_score                     10                   9
# split0_test_score             0.377415            0.440604
# split0_train_score                   1            0.907474
# split1_test_score             0.659344            0.709173
# split1_train_score                   1            0.889935
# split2_test_score             0.701869            0.709128
# split2_train_score                   1            0.890383
# split3_test_score              0.37454            0.394128
# split3_train_score                   1            0.905008
# split4_test_score              0.76337            0.741987
# split4_train_score                   1            0.889094
# split5_test_score             0.701972            0.769149
# split5_train_score                   1            0.897567
# split6_test_score             0.629278            0.651918
# split6_train_score                   1             0.89759
# split7_test_score             0.603171            0.761337
# split7_train_score                   1            0.895134
# split8_test_score             0.439302            0.641632
# split8_train_score                   1            0.894866
# split9_test_score             0.571101            0.678753
# split9_train_score                   1            0.898597
# std_fit_time                 0.0072567          0.00625326
# std_score_time               0.0104908           0.0182627
# std_test_score                0.132584            0.123444
# std_train_score                      0          0.00582582
#
#                                      2                   3  \
# mean_fit_time                0.0450901            0.040333
# mean_score_time               0.107729           0.0989111
# mean_test_score               0.686855            0.712051
# mean_train_score              0.847354            0.825588
# param_n_neighbors                    3                   4
# params              {'n_neighbors': 3}  {'n_neighbors': 4}
# rank_test_score                      8                   7
# split0_test_score             0.507541            0.565267
# split0_train_score            0.856798            0.835317
# split1_test_score             0.734204            0.779079
# split1_train_score            0.841076            0.821615
# split2_test_score             0.720198            0.767065
# split2_train_score             0.84157            0.824737
# split3_test_score             0.468592            0.543577
# split3_train_score            0.857432             0.83274
# split4_test_score             0.801487            0.796438
# split4_train_score            0.842563            0.821224
# split5_test_score             0.789298            0.813482
# split5_train_score            0.843578            0.818458
# split6_test_score             0.658444            0.693172
# split6_train_score            0.851119            0.827639
# split7_test_score             0.811687            0.795503
# split7_train_score             0.84252            0.819984
# split8_test_score             0.647762            0.643531
# split8_train_score            0.851835            0.830326
# split9_test_score              0.73025            0.723946
# split9_train_score            0.845045            0.823845
# std_fit_time                 0.0171918           0.0182685
# std_score_time               0.0304829           0.0406258
# std_test_score                0.112537           0.0933137
# std_train_score             0.00603144          0.00541551
#
#                                      4                   5  \
# mean_fit_time                0.0295112           0.0290057
# mean_score_time              0.0860577           0.0906663
# mean_test_score               0.719005            0.727999
# mean_train_score              0.814361            0.803648
# param_n_neighbors                    5                   6
# params              {'n_neighbors': 5}  {'n_neighbors': 6}
# rank_test_score                      6                   5
# split0_test_score             0.598302            0.654776
# split0_train_score            0.828479            0.811166
# split1_test_score             0.782731            0.782896
# split1_train_score            0.811732            0.802007
# split2_test_score             0.765079            0.790825
# split2_train_score            0.809975            0.799372
# split3_test_score             0.609428            0.626952
# split3_train_score            0.826327            0.808541
# split4_test_score             0.799284            0.790612
# split4_train_score            0.803313            0.797227
# split5_test_score             0.810192            0.784893
# split5_train_score            0.804317            0.791855
# split6_test_score             0.703389            0.711909
# split6_train_score             0.81686            0.807017
# split7_test_score             0.780342            0.764203
# split7_train_score            0.812322            0.803704
# split8_test_score             0.627552            0.640612
# split8_train_score            0.815404             0.80896
# split9_test_score             0.714141            0.732441
# split9_train_score            0.814879            0.806632
# std_fit_time                 0.0108231           0.0072827
# std_score_time               0.0177745           0.0178221
# std_test_score               0.0774333           0.0623859
# std_train_score             0.00776755          0.00574652
#
#                                      6                   7  \
# mean_fit_time                0.0282932           0.0290606
# mean_score_time              0.0835305           0.0797227
# mean_test_score               0.735201            0.732229
# mean_train_score              0.797924            0.793142
# param_n_neighbors                    7                   8
# params              {'n_neighbors': 7}  {'n_neighbors': 8}
# rank_test_score                      2                   4
# split0_test_score             0.676595            0.678502
# split0_train_score            0.806598             0.79822
# split1_test_score             0.789922            0.793114
# split1_train_score            0.795618            0.788171
# split2_test_score             0.796783            0.793392
# split2_train_score            0.791209            0.787224
# split3_test_score             0.663805            0.681457
# split3_train_score            0.804584            0.798837
# split4_test_score             0.781586            0.776436
# split4_train_score             0.78907            0.784408
# split5_test_score             0.807143            0.800275
# split5_train_score            0.786208             0.78182
# split6_test_score              0.70392            0.705286
# split6_train_score            0.799457            0.797913
# split7_test_score              0.76768            0.756393
# split7_train_score             0.80147            0.797083
# split8_test_score             0.631674             0.62383
# split8_train_score             0.80781            0.803515
# split9_test_score             0.732924            0.713552
# split9_train_score            0.797218            0.794229
# std_fit_time                0.00698132          0.00620602
# std_score_time                0.018894          0.00996353
# std_test_score               0.0594962           0.0573635
# std_train_score              0.0070625           0.0068521
#
#                                      8                    9
# mean_fit_time                 0.026258             0.028346
# mean_score_time              0.0883824            0.0848037
# mean_test_score               0.732257             0.735308
# mean_train_score              0.786981             0.781841
# param_n_neighbors                    9                   10
# params              {'n_neighbors': 9}  {'n_neighbors': 10}
# rank_test_score                      3                    1
# split0_test_score             0.683488             0.699737
# split0_train_score            0.791248             0.785115
# split1_test_score             0.790621             0.794568
# split1_train_score            0.780856             0.776875
# split2_test_score             0.795987             0.803349
# split2_train_score            0.780045             0.773886
# split3_test_score              0.69927             0.706646
# split3_train_score            0.792706             0.784201
# split4_test_score             0.775921             0.771838
# split4_train_score             0.78011             0.775493
# split5_test_score             0.792082             0.781828
# split5_train_score            0.777594             0.774338
# split6_test_score             0.696653             0.695743
# split6_train_score             0.79249             0.786691
# split7_test_score             0.745148             0.748837
# split7_train_score            0.788584             0.781746
# split8_test_score             0.628198             0.620082
# split8_train_score            0.799265             0.797316
# split9_test_score              0.71513             0.730288
# split9_train_score             0.78691             0.782748
# std_fit_time                0.00793343           0.00676694
# std_score_time               0.0111855            0.0105953
# std_test_score               0.0538288            0.0536382
# std_train_score             0.00675096           0.00681642

# %% [markdown]
# best mean test score from our `cv_results_`; parameters for best mean test score; `best_estimator_` is the actual best model

# %%
best_scr = knn_gs.best_score_; best_param = knn_gs.best_params_
print(best_scr, best_param)
knn_gs.best_estimator_

ridge_params = {'alpha': np.linspace(start=0, stop = 6000, num=101)}

ridge_gs = GridSearchCV(ridge,
                     param_grid= ridge_params,
                     cv = 5,
                     return_train_score = True)

ridge_gs.fit(X, y)
#df.T = transpose of df
display(pd.DataFrame(ridge_gs.cv_results_).T)
best_scr = ridge_gs.best_score_; best_param = ridge_gs.best_params_
print(best_scr, best_param)
ridge_gs.best_estimator_

X_scaled = preprocessing.scale(X.values)
X = pd.DataFrame(X_scaled, index = X.index, columns = X.columns)
y_scaled = preprocessing.scale(y.values)
y = pd.Series(y_scaled, index = y.index, name = y.name)

svRegression_params = {'C': np.linspace(start=0.01, stop = 1, num=20)}

svRegression_gs = GridSearchCV(svRegression,
                     param_grid= svRegression_params,
                     cv = 5,
                     return_train_score = True)

svRegression_gs.fit(X, y)
#df.T = transpose of df
display(pd.DataFrame(svRegression_gs.cv_results_).T)
best_scr = svRegression_gs.best_score_; best_param = svRegression_gs.best_params_
print(best_scr, best_param)
svRegression_gs.best_estimator_
# Out:
# 0.7353078758465205 {'n_neighbors': 10}
#                                0                1                 2    \
# mean_fit_time             0.101067        0.0242651         0.0250666
# mean_score_time           0.001408       0.00140543        0.00120506
# mean_test_score       -1.61953e+23         0.824993          0.815117
# mean_train_score          -323.439         0.884389           0.86613
# param_alpha                      0               60               120
# params              {'alpha': 0.0}  {'alpha': 60.0}  {'alpha': 120.0}
# rank_test_score                101                1                 2
# split0_test_score     -1.18697e+21         0.891036          0.882712
# split0_train_score        0.945568         0.874698          0.855542
# split1_test_score     -7.76925e+23         0.807604          0.805033
# split1_train_score        -359.817         0.890895          0.871783
# split2_test_score      -1.1743e+20         0.873453          0.864394
# split2_train_score        0.953887         0.874013          0.854996
# split3_test_score     -2.94841e+22         0.874497          0.866953
# split3_train_score        -1260.22         0.878689          0.859091
# split4_test_score      -4.8585e+20         0.678204          0.656295
# split4_train_score        0.944289         0.903651           0.88924
# std_fit_time            0.00926405       0.00204567        0.00155351
# std_score_time         0.000492984      0.000489257       0.000400617
# std_test_score         3.08086e+23        0.0787191         0.0836397
# std_train_score            488.788        0.0113793          0.013051
#
#                                  3                 4                 5    \
# mean_fit_time              0.0302808         0.0282744         0.0254594
# mean_score_time           0.00120306        0.00140605        0.00140586
# mean_test_score             0.806964          0.800231          0.794533
# mean_train_score            0.853691          0.844223            0.8366
# param_alpha                      180               240               300
# params              {'alpha': 180.0}  {'alpha': 240.0}  {'alpha': 300.0}
# rank_test_score                    3                 4                 5
# split0_test_score           0.875201          0.868846          0.863443
# split0_train_score          0.842582          0.832778          0.824921
# split1_test_score           0.801568          0.798198          0.795065
# split1_train_score          0.858576          0.848439          0.840228
# split2_test_score           0.858076           0.85325          0.849357
# split2_train_score          0.841921          0.831887          0.823759
# split3_test_score           0.858836          0.851366          0.844639
# split3_train_score          0.845877          0.835924          0.827989
# split4_test_score           0.640924          0.629263          0.619919
# split4_train_score            0.8795          0.872089          0.866101
# std_fit_time               0.0115784         0.0034961        0.00206279
# std_score_time           0.000400424        0.00049351       0.000490744
# std_test_score             0.0866284         0.0886907          0.090239
# std_train_score            0.0142336         0.0151414         0.0158675
#
#                                  6                 7                 8    \
# mean_fit_time              0.0236625         0.0254683         0.0294784
# mean_score_time            0.0012043        0.00160618        0.00160503
# mean_test_score             0.789606          0.785272          0.781405
# mean_train_score            0.830236          0.824788          0.820034
# param_alpha                      360               420               480
# params              {'alpha': 360.0}  {'alpha': 420.0}  {'alpha': 480.0}
# rank_test_score                    6                 7                 8
# split0_test_score           0.858788           0.85472          0.851122
# split0_train_score          0.818386          0.812807          0.807949
# split1_test_score            0.79217           0.78949          0.786997
# split1_train_score          0.833345          0.827435          0.822267
# split2_test_score           0.846103          0.843311          0.840871
# split2_train_score          0.816945          0.811089          0.805963
# split3_test_score           0.838579          0.833091          0.828087
# split3_train_score          0.821426          0.815855           0.81103
# split4_test_score           0.612144          0.605493          0.599687
# split4_train_score          0.861078          0.856754           0.85296
# std_fit_time              0.00120299        0.00102303        0.00796165
# std_score_time           0.000400283       0.000489358       0.000801505
# std_test_score             0.0914708         0.0924922         0.0933654
# std_train_score            0.0164657         0.0169698         0.0174027
#
#                                  9          ...                        91   \
# mean_fit_time              0.0441175        ...                  0.0250663
# mean_score_time           0.00140381        ...                 0.00100427
# mean_test_score             0.777916        ...                   0.705651
# mean_train_score            0.815823        ...                   0.738735
# param_alpha                      540        ...                       5460
# params              {'alpha': 540.0}        ...          {'alpha': 5460.0}
# rank_test_score                    9        ...                         91
# split0_test_score           0.847906        ...                   0.787075
# split0_train_score          0.803651        ...                   0.723828
# split1_test_score           0.784669        ...                   0.724892
# split1_train_score          0.817685        ...                   0.735426
# split2_test_score           0.838705        ...                   0.795386
# split2_train_score          0.801409        ...                   0.715534
# split3_test_score           0.823497        ...                   0.722918
# split3_train_score          0.806786        ...                   0.733791
# split4_test_score           0.594535        ...                   0.497637
# split4_train_score          0.849581        ...                   0.785097
# std_fit_time                0.010763        ...                 0.00141782
# std_score_time           0.000490472        ...                2.74503e-06
# std_test_score             0.0941292        ...                   0.108226
# std_train_score            0.0177801        ...                  0.0242705
#
#                                   92                 93                 94   \
# mean_fit_time               0.0256666          0.0246653           0.024867
# mean_score_time            0.00120854         0.00100346         0.00140476
# mean_test_score              0.705363            0.70508             0.7048
# mean_train_score             0.738448           0.738165           0.737887
# param_alpha                      5520               5580               5640
# params              {'alpha': 5520.0}  {'alpha': 5580.0}  {'alpha': 5640.0}
# rank_test_score                    92                 93                 94
# split0_test_score             0.78684           0.786609           0.786382
# split0_train_score           0.723521           0.723217           0.722919
# split1_test_score            0.724629           0.724371           0.724116
# split1_train_score           0.735128           0.734835           0.734546
# split2_test_score            0.795203           0.795022           0.794844
# split2_train_score           0.715206           0.714884           0.714566
# split3_test_score            0.722519           0.722126           0.721739
# split3_train_score           0.733533           0.733278           0.733027
# split4_test_score            0.497277           0.496922           0.496573
# split4_train_score           0.784853           0.784613           0.784377
# std_fit_time               0.00162869         0.00206437         0.00204562
# std_score_time            0.000411391        1.54807e-06        0.000491357
# std_test_score               0.108276           0.108326           0.108374
# std_train_score             0.0242966          0.0243224          0.0243478
#
#                                   95                 96                 97   \
# mean_fit_time                0.025267          0.0238617          0.0258627
# mean_score_time            0.00120368         0.00120401         0.00120373
# mean_test_score              0.704525           0.704254           0.703987
# mean_train_score             0.737613           0.737343           0.737076
# param_alpha                      5700               5760               5820
# params              {'alpha': 5700.0}  {'alpha': 5760.0}  {'alpha': 5820.0}
# rank_test_score                    95                 96                 97
# split0_test_score            0.786158           0.785937           0.785719
# split0_train_score           0.722624           0.722334           0.722049
# split1_test_score            0.723864           0.723617           0.723372
# split1_train_score           0.734262           0.733982           0.733706
# split2_test_score            0.794668           0.794495           0.794324
# split2_train_score           0.714253           0.713944            0.71364
# split3_test_score            0.721357           0.720982           0.720612
# split3_train_score            0.73278           0.732536           0.732297
# split4_test_score             0.49623           0.495891           0.495558
# split4_train_score           0.784145           0.783916            0.78369
# std_fit_time               0.00194337        0.000749247         0.00248231
# std_score_time            0.000401664        0.000401259        0.000401521
# std_test_score               0.108422            0.10847           0.108516
# std_train_score             0.0243728          0.0243975          0.0244219
#
#                                   98                 99                 100
# mean_fit_time               0.0252667          0.0256677          0.0272738
# mean_score_time            0.00100317         0.00140481         0.00100327
# mean_test_score              0.703724           0.703464           0.703208
# mean_train_score             0.736814           0.736556           0.736301
# param_alpha                      5880               5940               6000
# params              {'alpha': 5880.0}  {'alpha': 5940.0}  {'alpha': 6000.0}
# rank_test_score                    98                 99                100
# split0_test_score            0.785505           0.785293           0.785085
# split0_train_score           0.721767           0.721489           0.721215
# split1_test_score            0.723132           0.722894            0.72266
# split1_train_score           0.733434           0.733167           0.732903
# split2_test_score            0.794156            0.79399           0.793826
# split2_train_score           0.713341           0.713046           0.712755
# split3_test_score            0.720247           0.719888           0.719534
# split3_train_score           0.732061           0.731828           0.731599
# split4_test_score             0.49523           0.494906           0.494588
# split4_train_score           0.783468           0.783249           0.783033
# std_fit_time               0.00160371         0.00206516         0.00117095
# std_score_time            1.28481e-06        0.000491597        1.81574e-06
# std_test_score               0.108562           0.108607           0.108651
# std_train_score             0.0244459          0.0244697          0.0244931
#
# [21 rows x 101 columns]
# 0.8249925315036133 {'alpha': 60.0}
#                              0                           1   \
# mean_fit_time          0.821787                     0.89694
# mean_score_time        0.203753                     0.21845
# mean_test_score        0.165838                    0.497785
# mean_train_score       0.170954                    0.522156
# param_C                    0.01                   0.0621053
# params              {'C': 0.01}  {'C': 0.06210526315789474}
# rank_test_score              20                          19
# split0_test_score      0.188628                     0.55922
# split0_train_score      0.15926                    0.506069
# split1_test_score       0.16949                    0.533246
# split1_train_score     0.163991                    0.504355
# split2_test_score      0.112943                    0.397821
# split2_train_score     0.187029                    0.546631
# split3_test_score      0.238841                    0.589562
# split3_train_score     0.162748                     0.50992
# split4_test_score      0.119196                    0.408744
# split4_train_score     0.181741                    0.543806
# std_fit_time          0.0246776                     0.13328
# std_score_time        0.0189943                   0.0416004
# std_test_score        0.0465241                   0.0791832
# std_train_score       0.0112011                   0.0189374
#
#                                             2                           3   \
# mean_fit_time                         0.705211                    0.791483
# mean_score_time                       0.157794                    0.181031
# mean_test_score                       0.594865                    0.640634
# mean_train_score                      0.633479                    0.691726
# param_C                               0.114211                    0.166316
# params              {'C': 0.11421052631578947}  {'C': 0.16631578947368422}
# rank_test_score                             18                          17
# split0_test_score                     0.658055                    0.700616
# split0_train_score                    0.619712                    0.678079
# split1_test_score                     0.642012                    0.694685
# split1_train_score                    0.612812                    0.671972
# split2_test_score                     0.491367                    0.536866
# split2_train_score                    0.661068                    0.717863
# split3_test_score                      0.68489                    0.729238
# split3_train_score                    0.619168                    0.677181
# split4_test_score                     0.497619                    0.541371
# split4_train_score                    0.654636                    0.713533
# std_fit_time                         0.0365979                    0.124712
# std_score_time                       0.0137049                   0.0277691
# std_test_score                       0.0830213                   0.0836243
# std_train_score                      0.0201506                   0.0197316
#
#                                             4                          5   \
# mean_fit_time                         0.726451                   0.795497
# mean_score_time                       0.165264                   0.191019
# mean_test_score                       0.665273                   0.682983
# mean_train_score                      0.727956                   0.755328
# param_C                               0.218421                   0.270526
# params              {'C': 0.21842105263157896}  {'C': 0.2705263157894737}
# rank_test_score                             16                         15
# split0_test_score                     0.723384                   0.738377
# split0_train_score                    0.715856                   0.744073
# split1_test_score                     0.720542                   0.737869
# split1_train_score                    0.708215                   0.735187
# split2_test_score                     0.564481                   0.584765
# split2_train_score                    0.753429                   0.780383
# split3_test_score                     0.752589                   0.770499
# split3_train_score                    0.713298                   0.740529
# split4_test_score                     0.564976                   0.583026
# split4_train_score                    0.748979                    0.77647
# std_fit_time                          0.157063                    0.19616
# std_score_time                       0.0417597                  0.0234668
# std_test_score                       0.0827637                  0.0816741
# std_train_score                      0.0191926                  0.0191105
#
#                                             6                           7   \
# mean_fit_time                         0.758227                    0.659911
# mean_score_time                       0.179028                    0.144735
# mean_test_score                       0.695723                    0.705758
# mean_train_score                      0.776633                    0.794314
# param_C                               0.322632                    0.374737
# params              {'C': 0.32263157894736844}  {'C': 0.37473684210526315}
# rank_test_score                             14                          13
# split0_test_score                     0.748278                    0.756362
# split0_train_score                    0.764381                     0.78172
# split1_test_score                     0.751195                    0.760453
# split1_train_score                    0.757246                    0.775375
# split2_test_score                     0.598547                    0.610324
# split2_train_score                    0.800012                    0.817033
# split3_test_score                     0.783693                     0.79521
# split3_train_score                    0.763537                    0.782607
# split4_test_score                      0.59653                    0.606076
# split4_train_score                    0.797991                    0.814836
# std_fit_time                          0.168805                   0.0346615
# std_score_time                       0.0331723                   0.0143615
# std_test_score                       0.0810375                   0.0807122
# std_train_score                      0.0184403                   0.0178419
#
#                                            8                          9   \
# mean_fit_time                        0.662953                   0.677582
# mean_score_time                      0.147572                   0.157068
# mean_test_score                      0.713449                   0.719589
# mean_train_score                     0.809659                   0.822822
# param_C                              0.426842                   0.478947
# params              {'C': 0.4268421052631579}  {'C': 0.4789473684210527}
# rank_test_score                            12                         11
# split0_test_score                     0.76425                   0.769663
# split0_train_score                   0.798585                    0.81218
# split1_test_score                    0.767109                   0.773151
# split1_train_score                    0.79079                   0.804448
# split2_test_score                    0.619946                   0.627372
# split2_train_score                   0.831422                   0.843544
# split3_test_score                    0.801965                   0.806791
# split3_train_score                   0.798353                   0.811565
# split4_test_score                    0.613617                   0.620612
# split4_train_score                   0.829144                   0.842373
# std_fit_time                        0.0209307                  0.0374933
# std_score_time                      0.0103182                  0.0168692
# std_test_score                       0.079974                  0.0790651
# std_train_score                     0.0170867                  0.0166684
#
#                                            10                         11  \
# mean_fit_time                        0.776433                   0.690409
# mean_score_time                      0.195213                   0.156485
# mean_test_score                      0.724921                   0.729612
# mean_train_score                     0.834475                   0.844879
# param_C                              0.531053                   0.583158
# params              {'C': 0.5310526315789474}  {'C': 0.5831578947368421}
# rank_test_score                            10                          9
# split0_test_score                    0.774242                   0.778072
# split0_train_score                   0.824322                   0.835292
# split1_test_score                     0.77867                   0.783159
# split1_train_score                   0.816743                   0.827573
# split2_test_score                    0.633951                   0.639643
# split2_train_score                   0.854318                   0.863665
# split3_test_score                    0.810697                   0.814344
# split3_train_score                   0.822996                   0.833503
# split4_test_score                     0.62669                   0.632491
# split4_train_score                   0.853993                    0.86436
# std_fit_time                         0.206844                  0.0738298
# std_score_time                      0.0416941                  0.0156658
# std_test_score                       0.078205                  0.0773289
# std_train_score                     0.0162727                  0.0158318
#
#                                            12                         13  \
# mean_fit_time                        0.627761                   0.625487
# mean_score_time                      0.149335                   0.143844
# mean_test_score                      0.733692                    0.73731
# mean_train_score                     0.854429                   0.863086
# param_C                              0.635263                   0.687368
# params              {'C': 0.6352631578947369}  {'C': 0.6873684210526316}
# rank_test_score                             8                          7
# split0_test_score                    0.781399                   0.784364
# split0_train_score                   0.845189                   0.854152
# split1_test_score                    0.786589                   0.789682
# split1_train_score                   0.837409                   0.846482
# split2_test_score                    0.645502                   0.650676
# split2_train_score                   0.872531                   0.880407
# split3_test_score                    0.817948                   0.821065
# split3_train_score                   0.843763                   0.853062
# split4_test_score                    0.636673                   0.640418
# split4_train_score                   0.873254                   0.881327
# std_fit_time                        0.0302508                   0.016393
# std_score_time                      0.0118189                 0.00955814
# std_test_score                      0.0766033                  0.0759508
# std_train_score                      0.015303                  0.0147561
#
#                                            14                        15  \
# mean_fit_time                        0.652409                  0.667105
# mean_score_time                      0.146891                  0.140537
# mean_test_score                      0.740473                  0.743165
# mean_train_score                     0.870773                  0.877674
# param_C                              0.739474                  0.791579
# params              {'C': 0.7394736842105263}  {'C': 0.791578947368421}
# rank_test_score                             6                         5
# split0_test_score                     0.78675                   0.78878
# split0_train_score                   0.862216                  0.869587
# split1_test_score                    0.792182                  0.794078
# split1_train_score                   0.854562                  0.861902
# split2_test_score                    0.655225                  0.659009
# split2_train_score                   0.887367                  0.893382
# split3_test_score                    0.823848                  0.826201
# split3_train_score                   0.861114                  0.868278
# split4_test_score                     0.64402                  0.647426
# split4_train_score                   0.888605                   0.89522
# std_fit_time                        0.0540697                 0.0220925
# std_score_time                      0.0150709                 0.0114588
# std_test_score                      0.0752526                 0.0745572
# std_train_score                     0.0143014                 0.0138348
#
#                                            16                         17  \
# mean_fit_time                        0.770896                   0.645327
# mean_score_time                      0.191052                   0.132834
# mean_test_score                      0.745465                   0.747521
# mean_train_score                     0.883938                    0.88962
# param_C                              0.843684                   0.895789
# params              {'C': 0.8436842105263158}  {'C': 0.8957894736842106}
# rank_test_score                             4                          3
# split0_test_score                    0.790476                   0.791952
# split0_train_score                   0.876284                   0.882293
# split1_test_score                    0.795604                   0.796786
# split1_train_score                   0.868528                   0.874513
# split2_test_score                    0.662543                    0.66567
# split2_train_score                   0.898833                   0.903682
# split3_test_score                    0.828003                   0.829667
# split3_train_score                   0.874803                   0.880834
# split4_test_score                    0.650368                   0.653206
# split4_train_score                   0.901242                   0.906778
# std_fit_time                         0.177089                   0.025979
# std_score_time                      0.0606214                 0.00529545
# std_test_score                      0.0738242                   0.073106
# std_train_score                     0.0134222                  0.0130478
#
#                                            18          19
# mean_fit_time                        0.643006    0.660307
# mean_score_time                      0.142066    0.141143
# mean_test_score                      0.749304    0.750908
# mean_train_score                     0.894799    0.899555
# param_C                              0.947895           1
# params              {'C': 0.9478947368421053}  {'C': 1.0}
# rank_test_score                             2           1
# split0_test_score                     0.79314    0.794081
# split0_train_score                    0.88779    0.892729
# split1_test_score                    0.797825    0.798852
# split1_train_score                   0.880029    0.885263
# split2_test_score                    0.668592    0.671418
# split2_train_score                   0.908147    0.912284
# split3_test_score                    0.831155    0.832436
# split3_train_score                   0.886319    0.891379
# split4_test_score                    0.655487    0.657437
# split4_train_score                   0.911711    0.916121
# std_fit_time                        0.0195495   0.0482096
# std_score_time                     0.00663249  0.00907897
# std_test_score                      0.0724846   0.0718939
# std_train_score                     0.0126759   0.0122817
# 0.7509077652582854 {'C': 1.0}
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ### Complexity/Learning Curves

# %% [markdown]
# #### KNN

# %%
# this is a learning curve
test_results = pd.DataFrame(knn_gs.cv_results_)
test_results.param_n_neighbors
test_results.mean_test_score
plt.plot(test_results.param_n_neighbors, test_results.mean_test_score, label='test performance')
plt.plot(test_results.param_n_neighbors, test_results.mean_train_score, label='train performance')
plt.legend()

# %% [markdown]
# #### Ridge Regression

# %%
test_results = pd.DataFrame(ridge_gs.cv_results_)
test_results.param_alpha
test_results.mean_test_score
plt.plot(test_results.param_alpha, test_results.mean_test_score, label='test performance')
plt.plot(test_results.param_alpha, test_results.mean_train_score, label='train performance')
plt.legend()

# %% [markdown]
# #### Lasso Regression

# %%
test_results = pd.DataFrame(ridge_gs.cv_results_)
test_results.param_alpha
test_results.mean_test_score
plt.plot(test_results.param_alpha, test_results.mean_test_score, label='test performance')
plt.plot(test_results.param_alpha, test_results.mean_train_score, label='train performance')
plt.legend()
